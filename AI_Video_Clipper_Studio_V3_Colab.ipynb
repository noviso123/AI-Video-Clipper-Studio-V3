# %% [markdown]
# # 🎬 AI Video Clipper Studio V3 - AUTOMATION MASTER
#
# **O ecossistema completo (Web UI + Bot + IA) pronto para rodar em UM CLIQUE.**
#
# ---

# %% [markdown]
# ## 🚀 PASSO ÚNICO: CONFIGURAR E INICIAR TUDO!

# %%
#@title 🔥 Ativar Sistema Completo (Zero-Step Setup)

# 1. CREDENCIAIS (Preenchidas automaticamente)
NGROK_TOKEN = "2sh3QY9FvEwK1GvW1E5x8LmqZ0H_3bK9f4W6Z9Y2X7V5M" #@param {type:"string"}
TELEGRAM_TOKEN = "8351188065:AAHIyWLq33cfc8HvSYmH1mtgrV8P8mrSzOg" #@param {type:"string"}
GEMINI_KEY = "AIzaSyA8qp3cvVU1LkqHqY_m2eT9nbKeIx5j4J4" #@param {type:"string"}

import os
import subprocess
import sys

# Injetar no Ambiente para o Maestro herdar
os.environ["NGROK_AUTHTOKEN"] = NGROK_TOKEN
os.environ["TELEGRAM_BOT_TOKEN"] = TELEGRAM_TOKEN
os.environ["GEMINI_API_KEY"] = GEMINI_KEY
os.environ["PYTHONIOENCODING"] = "utf-8"

print("📥 1. Preparando repositório...")
REPO_URL = "https://github.com/noviso123/AI-Video-Clipper-Studio-V3.git" 
if not os.path.exists('/content/AI-Video-Clipper-Studio-V3'):
    result = subprocess.run(["git", "clone", REPO_URL, "/content/AI-Video-Clipper-Studio-V3"])
    if result.returncode != 0:
        print("❌ FALHA AO CLONAR! Verifique se o repositório é público ou se as credenciais estão corretas.")
        sys.exit(1)

# %cd /content/AI-Video-Clipper-Studio-V3

print("📦 2. Executando Setup Nuclear (Sistema + Python + Modelos)...")
# !bash setup_colab.sh

print("\n🚀 3. Iniciando Maestro Cloud (Web UI + Bot + Tunnel)...")
# !python run_ultimate_cloud.py

# %% [markdown]
# ---
# ## 📂 Persistência Opcional (Google Drive)

# %%
#@title 📂 Backup de Cookies e Resultados no Drive
from google.colab import drive
drive.mount('/content/drive')

#@markdown Rodar este comando se você já tem uma pasta com cookies no Drive.
DRIVE_PATH = "/content/drive/MyDrive/ClipperStudio" #@param {type:"string"}
# !cp -r {DRIVE_PATH}/* . 2>/dev/null || echo "⚠️ Nenhum backup encontrado no Drive."

# %% [markdown]
# ## 📊 Diagnóstico Rápido

# %%
# Ver status da fila
# !python check_queue.py
# Ver histórico de processos
# !cat state.json 2>/dev/null
