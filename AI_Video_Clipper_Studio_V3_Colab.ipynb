# %% [markdown]
# # 🎬 AI Video Clipper Studio V3 - ULTIMATE CLOUD ENGINE
#
# **O sistema de produção viral mais avançado, agora 100% pronto para Nuvem.**
#
# ---

# %% [markdown]
# ## 1️⃣ Configuração de Ambiente Profissional ⚙️

# %%
#@title 🚀 Instalação e Montagem (Execute para Iniciar)
import os
import sys
from google.colab import drive, userdata

# 1. Montar Google Drive para salvar progresso e cookies
if not os.path.exists('/content/drive'):
    drive.mount('/content/drive')

# 2. Parâmetros de Instalação
REPO_URL = "https://github.com/seu-usuario/AI-Video-Clipper-Studio-V3.git" #@param {type:"string"}
BRANCH = "main" #@param {type:"string"}

# 3. Clonar ou Atualizar
if not os.path.exists('AI-Video-Clipper-Studio-V3'):
    print("📥 Clonando repositório...")
    # !git clone -b {BRANCH} {REPO_URL}
else:
    print("🔄 Repositório já existe. Atualizando para última versão...")
    # %cd AI-Video-Clipper-Studio-V3
    # !git pull

# %cd /content/AI-Video-Clipper-Studio-V3

# 4. Setup Automático de Dependências (FFmpeg, Fonts, Python Libs)
print("📦 Executando setup_colab.sh (Potencial Máximo 🚀)...")
# !bash setup_colab.sh

print("\n✅ AMBIENTE PRONTO!")

# %% [markdown]
# ## 2️⃣ Gestão de Segredos e Credenciais 🗝️

# %%
#@title 📂 Sincronizar Credenciais (via Google Drive)
#@markdown Defina a pasta no seu Drive que contém seus cookies e chaves API.
DRIVE_CONFIG_PATH = "/content/drive/MyDrive/ClipperStudio" #@param {type:"string"}

# !mkdir -p browser_profiles/cookies
# !mkdir -p logs temp exports

print("🔄 Sincronizando arquivos de configuração...")
# !cp {DRIVE_CONFIG_PATH}/.env . 2>/dev/null || echo "⚠️ .env não encontrado"
# !cp {DRIVE_CONFIG_PATH}/credentials.json . 2>/dev/null || echo "⚠️ credentials.json não encontrado"
# !cp -r {DRIVE_CONFIG_PATH}/cookies/* browser_profiles/cookies/ 2>/dev/null || echo "⚠️ Cookies não encontrados"
# !cp -r {DRIVE_CONFIG_PATH}/browser_profiles/* browser_profiles/ 2>/dev/null || echo "⚠️ Perfis completos não encontrados"

print("✅ Credenciais sincronizadas! Verificando chaves...")
from dotenv import load_dotenv
load_dotenv()

bot_ready = "SIM" if os.getenv("TELEGRAM_BOT_TOKEN") else "NÃO"
gemini_ready = "SIM" if os.getenv("GEMINI_API_KEY") else "NÃO"
print(f"📌 Bot de Telegram: {bot_ready}")
print(f"📌 Gemini AI Engine: {gemini_ready}")

# %% [markdown]
# ## 3️⃣ 🔥 INICIAR ECOSSISTEMA FULL-STACK 🌐🤖
#
# Esta célula inicia o **Maestro**, que gerencia:
# 1.  **Web UI (Frontend/Backend)** na porta 5000.
# 2.  **Telegram Bot** em background.
# 3.  **Túnel Ngrok** para acesso externo à Web UI.

# %%
#@title 🎬 Start All-in-One Dashboard (Ngrok + Web + Bot)
NGROK_TOKEN = "2sh3QY9FvEwK1GvW1E5x8LmqZ0H_3bK9f4W6Z9Y2X7V5M" #@param {type:"string"}

import os

# 1. Configurar Tokens Reais (Preenchidos Automaticamente)
os.environ["NGROK_AUTHTOKEN"] = NGROK_TOKEN
os.environ["TELEGRAM_BOT_TOKEN"] = "8351188065:AAHIyWLq33cfc8HvSYmH1mtgrV8P8mrSzOg"
os.environ["GEMINI_API_KEY"] = "AIzaSyA8qp3cvVU1LkqHqY_m2eT9nbKeIx5j4J4"
os.environ["TIKTOK_CLIENT_KEY"] = "aw85p4d7rjcqkae2"
os.environ["TIKTOK_CLIENT_SECRET"] = "ZzGFPTMVbY2Rd1lEUe6y9BWJJMqE10Vo"

print("🚀 Iniciando orquestrador maestro com credenciais configuradas...")
# !python run_ultimate_cloud.py

# %% [markdown]
# ## 4️⃣ Execução Manual (Se preferir via terminal) 🛠️

# %%
#@title 🎬 Gerar Clipes Manualmente
VIDEO_SOURCE = "" #@param {type:"string"}
VIDEO_URL = "" #@param {type:"string"}
MODO = "Gamer" #@param ["Podcast", "Gamer", "Viral", "Faceless"]
QUANTIDADE = 3 #@param {type:"slider", min:1, max:10, step:1}

cmd = f"!python main.py --clips {QUANTIDADE} --mode {MODO} --captions"
if VIDEO_URL:
    cmd += f" --url {VIDEO_URL}"
elif VIDEO_SOURCE:
    cmd += f" --file {VIDEO_SOURCE}"

print(f"🚀 Executando: {cmd}")
eval(cmd)

# %% [markdown]
# ## 📅 Agendamento & Publicação em Massa

# %%
#@title 🕒 Iniciar Scheduler (Roda em Background)
INTERVALO = 120 #@param {type:"integer"}

# !python mass_publisher.py exports/ {INTERVALO}

import subprocess
subprocess.Popen(['python', 'start_scheduler.py'])
print("📅 Motor de agendamento ativo!")

# %% [markdown]
# ---
#
# ## 📊 Diagnóstico e Manutenção
#
# - Se o bot cair, reinicie a célula **3️⃣**.
# - Verifique se o `TELEGRAM_BOT_TOKEN` está correto no seu arquivo `.env` no Drive.
# - Os vídeos gerados ficam em `exports/` e também no seu histórico da Web UI.

# %%
#@title 🗑️ Limpar Cache e Temporários
# !rm -rf temp/* logs/*
# !python check_queue.py
print("🧹 Sistema limpo e pronto!")
