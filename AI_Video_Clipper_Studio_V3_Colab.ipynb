# %% [markdown]
# # 🎬 AI Video Clipper Studio V3 - MASTER ULTIMATE (V3.12)
#
# **O ecossistema definitivo para criação de cortes virais automatizados.**
#
# ---

# %% [markdown]
# ## 📁 1. MONTAR DRIVE E ESTRUTURA

# %%
#@title 🔥 Montar Google Drive
from google.colab import drive
import os

drive.mount('/content/drive')

BASE_PATH = "/content/drive/MyDrive/ClipperStudioV3"
os.makedirs(f"{BASE_PATH}/exports", exist_ok=True)
os.makedirs(f"{BASE_PATH}/cookies", exist_ok=True)
os.makedirs(f"{BASE_PATH}/temp", exist_ok=True)

print(f"✅ Estrutura no Drive pronta em: {BASE_PATH}")

# %% [markdown]
# ## 🚀 2. PASSO ÚNICO: INSTALAR E INICIAR

# %%
#@title 🔥 Ativar Sistema (Zero-Step Setup)

# 1. CREDENCIAIS
NGROK_TOKEN = "2sh3QY9FvEwK1GvW1E5x8LmqZ0H_3bK9f4W6Z9Y2X7V5M" #@param {type:"string"}
TELEGRAM_TOKEN = "" #@param {type:"string"}
GEMINI_KEY = "AIzaSyA8qp3cvVU1LkqHqY_m2eT9nbKeIx5j4J4" #@param {type:"string"}

# 2. CONFIGURAÇÕES
MANDATORY_HASHTAGS = "#viral, #clipper, #trending" #@param {type:"string"}
ENABLE_TELEGRAM_BOT = False #@param {type:"boolean"}

import os
import subprocess
import sys

# Ambiente
os.environ["NGROK_AUTHTOKEN"] = NGROK_TOKEN.strip()
os.environ["TELEGRAM_BOT_TOKEN"] = TELEGRAM_TOKEN.strip()
os.environ["GEMINI_API_KEY"] = GEMINI_KEY.strip()
os.environ["MANDATORY_HASHTAGS"] = MANDATORY_HASHTAGS
os.environ["ENABLE_TELEGRAM_BOT"] = str(ENABLE_TELEGRAM_BOT).lower()
os.environ["PYTHONIOENCODING"] = "utf-8"
os.environ["SDL_AUDIODRIVER"] = "dummy"

print("📥 1. Sincronizando código-fonte (Force Update)...")
REPO_URL = "https://github.com/noviso123/AI-Video-Clipper-Studio-V3.git"
TARGET_DIR = "/content/AI-Video-Clipper-Studio-V3"

if not os.path.exists(TARGET_DIR):
    subprocess.run(["git", "clone", REPO_URL, TARGET_DIR])
else:
    # %cd {TARGET_DIR}
    # !git fetch --all
    # !git reset --hard origin/main

# %cd {TARGET_DIR}

print("📦 2. Iniciando Setup Nuclear...")
# !bash setup_colab.sh

# Sincronizar cookies se existirem
# !cp -r /content/drive/MyDrive/ClipperStudioV3/cookies/* browser_profiles/cookies/ 2>/dev/null || true

print("\n🚀 3. Iniciando Maestro Cloud (Web UI + Tunnel)...")
print("⚠️ Caso o Ngrok falhe, verifique se seu token é válido.")
# !python run_ultimate_cloud.py
